# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import load_model
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import numpy as np
import matplotlib.pyplot as plt

# %%
datagen = ImageDataGenerator(rescale=1./255,
                            shear_range=0.2,
                            zoom_range=0.2,
                            rotation_range=45,
                            validation_split=0.2)

testDatagen = ImageDataGenerator(rescale=1./255,
                            shear_range=0.2,
                            zoom_range=0.2,
                            rotation_range=45)

trainData = datagen.flow_from_directory(directory='lung_train',
                                        batch_size=32,
                                        shuffle=False,
                                        target_size=(150,150),
                                        class_mode='categorical',
                                        subset='training',
                                        color_mode='rgb')

valData = datagen.flow_from_directory(directory='lung_train',
                                        batch_size=32,
                                        shuffle=False,
                                        target_size=(150,150),
                                        class_mode='categorical',
                                        subset='validation',
                                        color_mode='rgb')

testData = testDatagen.flow_from_directory(directory='lung_test',
                                        batch_size=32,
                                        shuffle=False,
                                        target_size=(150,150),
                                        class_mode='categorical',
                                        color_mode='rgb')
# Out:
# Found 10800 images belonging to 3 classes.
# Found 2700 images belonging to 3 classes.
# Found 1500 images belonging to 3 classes.

# %%
model = load_model('lungCancer_custom4.hdf5')
trainPred = np.argmax(model.predict_generator(trainData), axis=1)
valPred = np.argmax(model.predict_generator(valData), axis=1)
testPred = np.argmax(model.predict_generator(testData), axis=1)

cm = confusion_matrix(trainData.labels, trainPred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.title('Training Data Confusion Matrix for Custom-CNN')
plt.show()

cm = confusion_matrix(testData.labels, testPred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.title('Testing Data Confusion Matrix for Custom-CNN')
plt.show()

cm = confusion_matrix(valData.labels, valPred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.title('Validation Data Confusion Matrix for Custom-CNN')
plt.show()

print("\nCustom CNN Accuracies : ")
print("\nTraining Accuracy : ",accuracy_score(trainData.labels, trainPred))
print("\nTesting Accuracy : ",accuracy_score(testData.labels, testPred))
print("\nValidation Accuracy : ",accuracy_score(valData.labels, valPred))
# Out:
# C:\Users\raami\AppData\Local\Temp\ipykernel_192388\2488266882.py:2: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   trainPred = np.argmax(model.predict_generator(trainData), axis=1)
# C:\Users\raami\AppData\Local\Temp\ipykernel_192388\2488266882.py:3: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   valPred = np.argmax(model.predict_generator(valData), axis=1)
# C:\Users\raami\AppData\Local\Temp\ipykernel_192388\2488266882.py:4: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   testPred = np.argmax(model.predict_generator(testData), axis=1)
# Custom CNN Accuracies :
#
# Training Accuracy :  0.9591666666666666
#
# Testing Accuracy :  0.952
#
# ...

# %%
model = load_model('lungCancer_VGG16.hdf5')
trainPred = np.argmax(model.predict_generator(trainData), axis=1)
valPred = np.argmax(model.predict_generator(valData), axis=1)
testPred = np.argmax(model.predict_generator(testData), axis=1)

cm = confusion_matrix(trainData.labels, trainPred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.title('Training Data Confusion Matrix for VGG16')
plt.show()

cm = confusion_matrix(testData.labels, testPred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.title('Testing Data Confusion Matrix for VGG16')
plt.show()

cm = confusion_matrix(valData.labels, valPred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.title('Validation Data Confusion Matrix for VGG16')
plt.show()

print("\nVGG16 Accuracies : ")
print("\nTraining Accuracy : ",accuracy_score(trainData.labels, trainPred))
print("\nTesting Accuracy : ",accuracy_score(testData.labels, testPred))
print("\nValidation Accuracy : ",accuracy_score(valData.labels, valPred))
# Out:
# C:\Users\raami\AppData\Local\Temp\ipykernel_192388\1211501610.py:2: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   trainPred = np.argmax(model.predict_generator(trainData), axis=1)
# C:\Users\raami\AppData\Local\Temp\ipykernel_192388\1211501610.py:3: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   valPred = np.argmax(model.predict_generator(valData), axis=1)
# C:\Users\raami\AppData\Local\Temp\ipykernel_192388\1211501610.py:4: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   testPred = np.argmax(model.predict_generator(testData), axis=1)
# VGG16 Accuracies :
#
# Training Accuracy :  0.9464814814814815
#
# Testing Accuracy :  0.936
#
# ...

# %%
model = load_model('lungCancer_VGG16-1.hdf5')
trainPred = np.argmax(model.predict_generator(trainData), axis=1)
valPred = np.argmax(model.predict_generator(valData), axis=1)
testPred = np.argmax(model.predict_generator(testData), axis=1)

cm = confusion_matrix(trainData.labels, trainPred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.title('Training Data Confusion Matrix for VGG16')
plt.show()

cm = confusion_matrix(testData.labels, testPred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.title('Testing Data Confusion Matrix for VGG16')
plt.show()

cm = confusion_matrix(valData.labels, valPred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.title('Validation Data Confusion Matrix for VGG16')
plt.show()

print("\nVGG16 Accuracies : ")
print("\nTraining Accuracy : ",accuracy_score(trainData.labels, trainPred))
print("\nTesting Accuracy : ",accuracy_score(testData.labels, testPred))
print("\nValidation Accuracy : ",accuracy_score(valData.labels, valPred))
# Out:
# C:\Users\raami\AppData\Local\Temp\ipykernel_185756\2983084364.py:2: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   trainPred = np.argmax(model.predict_generator(trainData), axis=1)
# C:\Users\raami\AppData\Local\Temp\ipykernel_185756\2983084364.py:3: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   valPred = np.argmax(model.predict_generator(valData), axis=1)
# C:\Users\raami\AppData\Local\Temp\ipykernel_185756\2983084364.py:4: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   testPred = np.argmax(model.predict_generator(testData), axis=1)
# VGG16 Accuracies :
#
# Training Accuracy :  0.9255555555555556
#
# Testing Accuracy :  0.9173333333333333
#
# ...
